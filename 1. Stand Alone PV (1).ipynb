# %% [markdown]
# # **1. PVWatts 100MW - Single Owner Example**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# **1.1   Model Initialization**

# %%
import PySAM.Pvwattsv7 as pv
import PySAM.Singleowner as so
system_model = pv.default('PVWattsSingleOwner')

# %% [markdown]
# **1.2   SystemDesign Group**

# %%
system_model.SystemDesign.system_capacity=100000 #kW
system_model.SystemDesign.module_type=1
system_model.SystemDesign.array_type=3
system_model.SystemDesign.tilt=0
system_model.SystemDesign.azimuth=0

# %% [markdown]
# **1.3   SolarResource Group**

# %%
system_model.SolarResource.solar_resource_file="Antofagasta.csv"

# %% [markdown]
# **1.4.   Outputs Group**

# %%
system_model.execute()
gen_pv=np.array(system_model.Outputs.dc)/1000

month_pv=system_model.Outputs.dc_monthly

# %%
gen_pv.max()
# Out:
# 90553.19188549029

# %%
gen_pv.min()
# Out:
# 0.0

# %%
# %store gen_pv

# %store month_pv
# Out:
# Stored 'gen_pv' (ndarray)
# Stored 'month_pv' (tuple)

# %% [markdown]
# **CF - PV**

# %%
system_model.Outputs.capacity_factor
# Out:
# 28.966386556904826

# %%
gen_pv_limit=np.array(gen_pv)
for i in range(0,8760):
  if (gen_pv_limit[i]<100000*0.1):
    gen_pv_limit[i]=0

# %% [markdown]
# **CF - ALK - PV**

# %%
CF_pv_alk=sum(gen_pv_limit)/(100000*8760)

CF_pv_alk
# Out:
# 0.3007837064018366

# %% [markdown]
# **CF - PEM - PV**

# %%
CF_pv_PEM=sum(gen_pv)/(100000*8760)
CF_pv_PEM
# Out:
# 0.30184630409612756

# %% [markdown]
# # <center> $LCOE=\frac{\sum_{i=0}^{N}\frac{CAPEX_i}{\left(1+t\right)^i}+\sum_{i=1}^{N}\frac{OPEX_i}{\left(1+t\right)^i}}{\sum_{i=1}^{N}\frac{Production_i}{\left(1+t\right)^i}}$ <center>

# %% [markdown]
# #  <center> CAPEX required for a PV plant <center>
#
# | | Element  | CAPEX (USD/Wdc)    | Percent Distribution (%)   |
# |---:|:-------------:|:-----------:|:------:|
# | 1 | Module  | 0.41       |   |
# | 2 | Land preparation | 0.02   |   |
# | 3 | Balance of system | 0.2    |    |
# | 4 | Installation labor | 0.11    |    |
# | 5 | Contingency | 3%   |    |

# %%
def LCOE_pv(d,Module,Balance,Land_prep,Installation_labor,Contingency,percent_opex):
    Sum1=0
    Sum2=0
    t=0.07
    for i in range(1,31):
        Sum1 = Sum1 + (((1-d)**i)/((1+t)**i))
        Sum2 = Sum2 + (1/((1+t)**i))
    Production_pv=sum(gen_pv)
    CAPEX= ((Module + Installation_labor+Balance)*Contingency + Land_prep)*system_model.SystemDesign.system_capacity*1000
    OPEX=percent_opex*CAPEX
    LCOE_pv=((CAPEX+OPEX*Sum2)/(Production_pv*Sum1))*1000
    return LCOE_pv

# %% [markdown]
# **LCOE 2021**

# %%
LCOE_pv_2021=LCOE_pv(0.7/100,0.41,0.2,0.02,0.11,101/100,2/100) #USD/MWh
# %store LCOE_pv_2021
LCOE_pv_2021
# Out:
# Stored 'LCOE_pv_2021' (float64)
# 30.607326460784936

# %% [markdown]
# **LCOE 2030**

# %%
LCOE_pv_2030=LCOE_pv(0.5/100,0.17,0.1,0.01,0.11,101/100,1/100) #USD/MWh
# %store LCOE_pv_2030
LCOE_pv_2030
# Out:
# Stored 'LCOE_pv_2030' (float64)
# 14.22703412243445

# %% [markdown]
# # ${LCOH}_2=P_{inst}\bullet I\bullet\frac{FRC+M\left(f_p\right)}{h{\bullet f}_p\bullet Q_{H_2}}+Q_{H_2O}{\bullet P}_{H_2O}+Q_e\bullet P_e-Q_{O_2}\bullet P_{O_2}$

# %%
def LCOH(I,LCOE,f_p,eff,stack_lifetime=90000,percent_remp=0.4):
    P_inst=100 #Potencia instalada del electrolizador [MW]
    i=0.07
    h=8760 #Horas en un año
    N_rep=stack_lifetime/(f_p*h)
    I=I+I*percent_remp*(1-i)**N_rep
    n=30
    FRC=(i*((1+i)**n))/(((1+i)**n)-1)  #Factor de recuperación de capital
    M=0.017 #Función de costos de mantenimiento como un porcentaje de la inversión, dependiente del factor de planta
    Q_h2=20.3 #Capacidad de producción de hidrógeno [kg/h]
    Q_H2O=0.017  #Cantidad de agua consumida [m3/kg de hidrógeno]
    P_H2O=1.4 #Precio del agua [USD/m3]
    Q_e=33.3/eff  #Cantidad de electricidad consumida [kWh/kg de hidrógeno] 
    P_e=LCOE
    Q_O2=7.8 #Venta de oxígeno tomando en cuenta la cantidad producida [kgO2/kg de hidrógeno] (término opcional) 
    P_O2=0.03 #Precio de venta del oxígeno [USD/kgO2] (término opcional)
    #LCOH_2 = P_inst*I*((FRC+M)/(h*f_p*Q_h2))+Q_H2O*P_H2O+Q_e*P_e-Q_O2*P_O2
    LCOH = I*(FRC+M)*33.3/(h*f_p*eff)+Q_H2O*P_H2O+Q_e*P_e
    Water=Q_H2O*P_H2O
    Electricity=Q_e*P_e
    Electrolysis=I*(FRC+M)*33.3/(h*f_p*eff)
    
    return(LCOH,Water,Electricity,Electrolysis)

# %% [markdown]
# **LCOH - PV - ALK - 2021**

# %%
LCOH_pv_alk_2021=LCOH(500,LCOE_pv_2021/1000,CF_pv_alk,0.7,100000)[0]
LCOH_pv_alk_2021
# Out:
# 2.3832070215582943

# %% [markdown]
# **LCOH - PV - PEM - 2021**

# %%
LCOH_pv_PEM_2021=LCOH(1100,LCOE_pv_2021/1000,CF_pv_PEM,0.6)[0]
LCOH_pv_PEM_2021
# Out:
# 4.0518549436528595

# %% [markdown]
# **LCOH - PV - ALK - 2030**

# %%
LCOH_pv_alk_2030=LCOH(400,LCOE_pv_2030/1000,CF_pv_alk,0.71,100000,0.15)[0]
LCOH_pv_alk_2030
# Out:
# 1.3925296682478425

# %% [markdown]
# **LCOH - PV - PEM - 2030**

# %%
LCOH_pv_PEM_2030=LCOH(650,LCOE_pv_2030/1000,CF_pv_PEM,0.68,percent_remp=0.2)[0]
LCOH_pv_PEM_2030
# Out:
# 1.9151346000830052

# %%
labels = ['PV-ALK-2021',"PV-PEM-2021","PV-ALK-2030","PV-PEM-2030"]
W = [LCOH(500,LCOE_pv_2021/1000,CF_pv_alk,0.63,100000)[1],LCOH(1100,LCOE_pv_2021/1000,CF_pv_PEM,0.56)[1],LCOH(400,LCOE_pv_2030/1000,CF_pv_alk,0.65,100000,0.15)[1],LCOH(650,LCOE_pv_2030/1000,CF_pv_PEM,0.63,percent_remp=0.2)[1]]
Electri = [LCOH(500,LCOE_pv_2021/1000,CF_pv_alk,0.63,100000)[2],LCOH(1100,LCOE_pv_2021/1000,CF_pv_PEM,0.56)[2],LCOH(400,LCOE_pv_2030/1000,CF_pv_alk,0.65,100000,0.15)[2],LCOH(650,LCOE_pv_2030/1000,CF_pv_PEM,0.63,percent_remp=0.2)[2]]
Electro = [LCOH(500,LCOE_pv_2021/1000,CF_pv_alk,0.63,100000)[3],LCOH(1100,LCOE_pv_2021/1000,CF_pv_PEM,0.56)[3],LCOH(400,LCOE_pv_2030/1000,CF_pv_alk,0.65,100000,0.15)[3],LCOH(650,LCOE_pv_2030/1000,CF_pv_PEM,0.63,percent_remp=0.2)[3]]
width = 0.5       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

bars = np.add(Electri, Electro).tolist()

ax.bar(labels, Electri, width, label='Electricity')
ax.bar(labels, Electro, width, bottom=Electri,label='Electrolysis')
ax.bar(labels, W, width, bottom=bars,label='Water')
ax.legend()

ax.set_ylabel("USD/kg")
#ax.set_title('Levelised Cost of Hydrogen - PV')

#ax.bar(labels, women_means, width, bottom=men_means,label='Women')

#Agua=W*100/(W+Electri+Electro)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'USD/kg')

# %%
i=3
Agua=W[i]*100/(W[i]+Electri[i]+Electro[i])
Agua
# Out:
# 1.1524081462265057

# %%
Electricidad=Electri[i]*100/(W[i]+Electri[i]+Electro[i])
Electricidad
# Out:
# 36.41224193970163

# %%
Electrolizador=Electro[i]*100/(W[i]+Electri[i]+Electro[i])
Electrolizador
# Out:
# 62.435349914071864

# %%
fig, ax = plt.subplots(figsize=(10, 4), tight_layout=True, facecolor='w')
#ax.plot(pd.date_range(start='1/1/2021', end='01/01/2022',periods=8760),gen_comb,label='CSP',c="tab:orange")
#ax.plot(pd.date_range(start='1/1/2021', end='01/01/2022',periods=8760),gen_pv,label='PV',c="tab:green")
ax.plot(pd.date_range(start='1/1/2021', end='01/01/2022',periods=8760),gen_pv)
#ax.plot(pd.date_range(start='1/1/2021', end='01/01/2022',periods=8760),gen_with_curtailment, c="tab:green")
ax.set_ylabel('kW')
ax.set_xlabel('Days of the year')
#ax.set_title('Hourly energy generated by the PV system and hydrogen production')
#ax.legend(loc=2, ncol=3, bbox_to_anchor=(0.7, 0.2))
fig.autofmt_xdate()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
fig, ax = plt.subplots(figsize=(10, 4), tight_layout=True, facecolor='w')
#ax.plot(pd.date_range(start='1/1/2021', end='01/01/2022',periods=8760),gen_comb,label='CSP',c="tab:orange")
#ax.plot(pd.date_range(start='1/1/2021', end='01/01/2022',periods=8760),gen_pv,label='PV',c="tab:green")
ax.plot(pd.date_range(start='1/1/2021', end='01/01/2022',periods=8760),gen_pv,c="tab:green")
#ax.plot(pd.date_range(start='1/1/2021', end='01/01/2022',periods=8760),gen_with_curtailment, c="tab:green")
ax.set_ylabel('kW')
ax.set_xlabel('Hours of the year')
ax.set_title('Hourly energy generated by the PV system and hydrogen production')
ax.legend(loc=2, ncol=3, bbox_to_anchor=(0.7, 0.2))
fig.autofmt_xdate()
ax2 = ax.twinx()
hydrogen_gen=gen_pv*0.63/33.3
ax2.set_ylabel('kg/h')  # we already handled the x-label with ax1
ax2.plot(pd.date_range(start='1/1/2021', end='01/01/2022',periods=8760),gen_pv*0.7/33.3,label='Hydrogen',c="tab:blue")
plt.savefig('Ejemplo.png')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# No handles with labels found to put in legend.

# %%
df1=pd.DataFrame(np.array(system_model.Outputs.dc_monthly))
df2=pd.DataFrame()
df3=pd.DataFrame()
df4=pd.DataFrame()
df5=pd.DataFrame()
df1["PEM"]=(df1[0]/66.4)*60
df1["Liq"]=(df1[0]/66.4)*6.4
df1["Alk"]=(df1[0]/60.4)*54
df1["Liq1"]=(df1[0]/60.4)*6.4
df1["PEM1"]=(df1[0]/61.05)*60
df1["Comp"]=(df1[0]/61.05)*1.05
df1["Alk1"]=(df1[0]/55.05)*54
df1["Comp1"]=(df1[0]/55.05)*1.05

Months=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sept","Oct","Nov","Dec"]
df1.index=Months


df1.columns=["Energy", "PEM","Liq","Alk","Liq1","PEM1","Comp","Alk1","Comp1"]

# %%
LHV=33.3 #(kWh/KgH2)
eff_PEM=0.56
eff_ALK=0.63

df1=pd.DataFrame(np.array(system_model.Outputs.dc_monthly))
df2=pd.DataFrame()
df3=pd.DataFrame()
df4=pd.DataFrame()
df5=pd.DataFrame()

df1["PEM"]=(df1[0]/(LHV/eff_PEM + 6.4))*(LHV/eff_PEM)
df1["Liq"]=(df1[0]/(LHV/eff_PEM + 6.4))*6.4
df1["Alk"]=(df1[0]/(LHV/eff_ALK + 6.4))*(LHV/eff_ALK)
df1["Liq1"]=(df1[0]/(LHV/eff_ALK + 6.4))*6.4
df1["PEM1"]=(df1[0]/(LHV/eff_PEM + 1.05))*(LHV/eff_PEM)
df1["Comp"]=(df1[0]/(LHV/eff_PEM + 1.05))*1.05
df1["Alk1"]=(df1[0]/(LHV/eff_ALK + 1.05))*(LHV/eff_ALK)
df1["Comp1"]=(df1[0]/(LHV/eff_ALK + 1.05))*1.05

Months=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sept","Oct","Nov","Dec"]
df1.index=Months


df1.columns=["Energy", "PEM","Liq","Alk","Liq1","PEM1","Comp","Alk1","Comp1"]

# %%
(2.693311e+06*100)/(2.502435e+07+2.693311e+06)
# Out:
# 9.716949060023499

# %%
df1["PEM"]
# Out:
# Jan     2.502435e+07
# Feb     2.141437e+07
# Mar     2.203429e+07
# Apr     1.767350e+07
# May     1.547812e+07
# Jun     1.354734e+07
# Jul     1.459684e+07
# Aug     1.717608e+07
# Sept    1.978852e+07
# Oct     2.331115e+07
# Nov     2.405979e+07
# Dec     2.461971e+07
# Name: PEM, dtype: float64

# %%
df1["Liq"]
# Out:
# Jan     2.693311e+06
# Feb     2.304778e+06
# Mar     2.371498e+06
# Apr     1.902157e+06
# May     1.665873e+06
# Jun     1.458068e+06
# Jul     1.571024e+06
# Aug     1.848621e+06
# Sept    2.129791e+06
# Oct     2.508924e+06
# Nov     2.589498e+06
# Dec     2.649761e+06
# Name: Liq, dtype: float64

# %%
x=range(12)
fig, ax = plt.subplots(2, 2,constrained_layout=False)
fig.set_size_inches(15, 10)

ax[0, 0].bar(x=range(12), # Posición de las barras
       height=df1["PEM"],
       label='PEM',
       width=0.8, bottom=0, align='center', # Ancho y alineación de las barras
       color=None, edgecolor=None, linewidth=None); # Color y otros aspectos estéticos
ax[0, 0].bar(x=range(12), # Posición de las barras
       height=df1["Liq"],
       bottom=df1["PEM"],
       label='Liq',
       #width=0.8, bottom=0, align='center', # Ancho y alineación de las barras
       color=None, edgecolor=None, linewidth=None); # Color y otros aspectos estéticos
ax[0, 0].set_ylabel('kWh')
#ax[0, 0].set_xlabel('Months')
#ax[0, 0].set_title('Monthly system power generated')
ax[0, 0].legend(loc=1, ncol=3, bbox_to_anchor=(0.65, 1))
ax[0, 0].set_xticklabels(Months)
ax[0, 0].set_xticks(range(12));


ax[0, 1].bar(x=range(12), # Posición de las barras
       height=df1["Alk"],
       label='Alk',
       width=0.8, bottom=0, align='center', # Ancho y alineación de las barras
       color=None, edgecolor=None, linewidth=None); # Color y otros aspectos estéticos
ax[0, 1].bar(x=range(12), # Posición de las barras
       height=df1["Liq1"],
       bottom=df1["Alk"],
       label='Liq',
       #width=0.8, bottom=0, align='center', # Ancho y alineación de las barras
       color=None, edgecolor=None, linewidth=None); # Color y otros aspectos estéticos
ax[0, 1].set_ylabel('kWh')
#ax[0, 1].set_xlabel('Months')
#ax[0, 1].set_title('Monthly system power generated')
ax[0, 1].legend(loc=1, ncol=3, bbox_to_anchor=(0.65, 1))
ax[0, 1].set_xticklabels(Months)
ax[0, 1].set_xticks(x);


ax[1, 0].bar(x=range(12), # Posición de las barras
       height=df1["PEM1"],
       label='PEM',
       width=0.8, bottom=0, align='center', # Ancho y alineación de las barras
       color=None, edgecolor=None, linewidth=None); # Color y otros aspectos estéticos
ax[1, 0].bar(x=range(12), # Posición de las barras
       height=df1["Comp"],
       bottom=df1["PEM1"],
       label='Comp',
       #width=0.8, bottom=0, align='center', # Ancho y alineación de las barras
       color=None, edgecolor=None, linewidth=None); # Color y otros aspectos estéticos
ax[1, 0].set_ylabel('kWh')
#ax[1, 0].set_xlabel('Months')
#ax[1, 0].set_title('Monthly system power generated')
ax[1, 0].legend(loc=1, ncol=3, bbox_to_anchor=(0.65, 1))
ax[1, 0].set_xticklabels(Months)
ax[1, 0].set_xticks(x);


ax[1, 1].bar(x=range(12), # Posición de las barras
       height=df1["Alk1"],
       label='Alk',
       width=0.8, bottom=0, align='center', # Ancho y alineación de las barras
       color=None, edgecolor=None, linewidth=None); # Color y otros aspectos estéticos
ax[1, 1].bar(x=range(12), # Posición de las barras
       height=df1["Comp1"],
       bottom=df1["Alk1"],
       label='Comp',
       #width=0.8, bottom=0, align='center', # Ancho y alineación de las barras
       color=None, edgecolor=None, linewidth=None); # Color y otros aspectos estéticos
ax[1, 1].set_ylabel('kWh')
#ax[1, 1].set_xlabel('Months')
#ax[1, 1].set_title('Monthly system power generated')
ax[1, 1].legend(loc=1, ncol=3, bbox_to_anchor=(0.65, 1))
ax[1, 1].set_xticklabels(Months)
ax[1, 1].set_xticks(x);
# Out:
# <img src="data:image/png;base64,..." width="1499.5555555555557">
# <ipython-input-32-aed72936600a>:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0, 0].set_xticklabels(Months)
# <ipython-input-32-aed72936600a>:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0, 1].set_xticklabels(Months)
# <ipython-input-32-aed72936600a>:58: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1, 0].set_xticklabels(Months)
# <ipython-input-32-aed72936600a>:77: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1, 1].set_xticklabels(Months)

# %%
#2021
comb=np.array(system_model.Outputs.dc_monthly)
LHV=33.3 #(kWh/KgH2)
eff_PEM=0.56
eff_ALK=0.63
H2_PEM_Liq=(comb/(LHV/eff_PEM+6.4))*(1/1000)
H2_PEM_Comp=(comb/(LHV/eff_PEM+1.05))*(1/1000)
H2_Alk_Liq=(comb/(LHV/eff_ALK+6.4))*(1/1000)
H2_Alk_Comp=(comb/(LHV/eff_ALK+1.05))*(1/1000)

# %%
xxxxx=sum(H2_Alk_Comp)/12
xxxxx
# Out:
# 408.7543696650876

# %%
yyyyyyy=sum(H2_PEM_Liq)/12
yyyyyyy
# Out:
# 334.54822989506744

# %%
fig, ax = plt.subplots(figsize=(8, 4), tight_layout=True, facecolor='w')
y=np.arange(12)
width1 = 0.2
ax.bar(y - 1.5*width1, # Posición de las barras
       height=H2_PEM_Liq,
       label="PEM - Liq",
       width=0.2); 

ax.bar(y +1.5*width1, # Posición de las barras
       height=H2_PEM_Comp,
       label='PEM - Comp',
       width=0.2); 

ax.bar(y-0.5*width1, # Posición de las barras
       height=H2_Alk_Liq,
       label='Alk - Liq',
       width=0.2); 

ax.bar(y + 0.5*width1, # Posición de las barras
       height=H2_Alk_Comp,
       label='Alk - Comp',
       width=0.2); 
       
ax.set_ylabel('Tons of hydrogen')
ax.set_xlabel('Months')
#ax.set_title('Monthly Hydrogen Production 2021')
ax.legend(loc=1, ncol=4, bbox_to_anchor=(1, 0.1))
ax.set_xticklabels(Months)
ax.set_xticks(y);
# Out:
# <img src="data:image/png;base64,..." width="800">
# <ipython-input-36-193f15773162>:28: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(Months)

# %%
#2030
comb=np.array(system_model.Outputs.dc_monthly)
LHV=33.3 #(kWh/KgH2)
eff_PEM=0.63
eff_ALK=0.65
H2_PEM_Liq=(comb/(LHV/eff_PEM+6.4))*(1/1000)
H2_PEM_Comp=(comb/(LHV/eff_PEM+1.05))*(1/1000)
H2_Alk_Liq=(comb/(LHV/eff_ALK+6.4))*(1/1000)
H2_Alk_Comp=(comb/(LHV/eff_ALK+1.05))*(1/1000)

# %%
sum(H2_Alk_Comp)/8760
# Out:
# 0.577356279445251

# %%
xxxxx=sum(H2_Alk_Comp)/12
xxxxx
# Out:
# 421.4700839950333

# %%
yyyyyyy=sum(H2_PEM_Liq)/12
yyyyyyy
# Out:
# 371.8501962225671

# %%
fig, ax = plt.subplots(figsize=(8, 4), tight_layout=True, facecolor='w')
y=np.arange(12)
width1 = 0.2
ax.bar(y - 1.5*width1, # Posición de las barras
       height=H2_PEM_Liq,
       label="PEM - Liq",
       width=0.2); 

ax.bar(y +1.5*width1, # Posición de las barras
       height=H2_PEM_Comp,
       label='PEM - Comp',
       width=0.2); 

ax.bar(y-0.5*width1, # Posición de las barras
       height=H2_Alk_Liq,
       label='Alk - Liq',
       width=0.2); 

ax.bar(y + 0.5*width1, # Posición de las barras
       height=H2_Alk_Comp,
       label='Alk - Comp',
       width=0.2); 
       
ax.set_ylabel('Tons of hydrogen')
ax.set_xlabel('Months')
#ax.set_title('Monthly Hydrogen Production 2030')
ax.legend(loc=1, ncol=4, bbox_to_anchor=(1, 0.1))
ax.set_xticklabels(Months)
ax.set_xticks(y);
# Out:
# <img src="data:image/png;base64,..." width="800">
# <ipython-input-41-6563bdf52066>:28: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(Months)

# %%
day_prod=(sum(gen_pv)/365)*0.63/33.3

# %%
day_prod
# Out:
# 13705.453807607955

# %%
flow_max=gen_pv.max()*0.63/33.3

# %%
flow_max
# Out:
# 1713.1684951308973

# %%
#Compressed hydrogen gas storage system

i=0.07
n_conversion=15
n_storage=20

FRC_conversion=(i*((1+i)**n_conversion))/(((1+i)**n_conversion)-1)
FRC_storage=(i*((1+i)**n_storage))/(((1+i)**n_storage)-1)

M_storage=2/100
M_conversion=4/100

storage_module=500*day_prod*((FRC_storage+M_storage)/(sum(gen_pv_limit)*0.63/33.3))  #USD
conversion_module=3900*flow_max*1.05*((FRC_conversion+M_conversion)/(sum(gen_pv_limit)*0.63/33.3))

GH2=storage_module+conversion_module

# %%
GH2  #USD/kg
# Out:
# 0.3680683077179385

# %%
#Liquid hydrogen

i=0.07
n_conversion=20
n_storage=20

FRC_conversion=(i*((1+i)**n_conversion))/(((1+i)**n_conversion)-1)
FRC_storage=(i*((1+i)**n_storage))/(((1+i)**n_storage)-1)

M_storage=2/100
M_conversion=8/100


storage_module=90*day_prod*((FRC_storage+M_storage)/(sum(gen_pv_limit)*0.63/33.3))  #USD
conversion_module=50000*flow_max*((FRC_conversion+M_conversion)/(sum(gen_pv_limit)*0.63/33.3))
LH2=storage_module+conversion_module

# %%
LH2
# Out:
# 3.025012681864771

# %%
LCOH_pv_PPA_2021=LCOH(500,54.7/1000,0.42,0.63,100000)[0]
LCOH_pv_PPA_2021
# Out:
# 3.6550790628069936

# %%
LCOH_pv_PPA_2030=LCOH(400,38.7/1000,0.42,0.65,100000,0.15)[0]
LCOH_pv_PPA_2030
# Out:
# 2.561306869385997
